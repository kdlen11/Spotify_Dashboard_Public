# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\winapp\python\python310\lib\site-packages (2.25.1)
# Requirement already satisfied: requests>=2.25.0 in c:\winapp\python\python310\lib\site-packages (from spotipy) (2.31.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\winapp\python\python310\lib\site-packages (from spotipy) (2.1.0)
# Requirement already satisfied: redis>=3.5.3 in c:\winapp\python\python310\lib\site-packages (from spotipy) (7.0.1)
# Requirement already satisfied: async-timeout>=4.0.3 in c:\winapp\python\python310\lib\site-packages (from redis>=3.5.3->spotipy) (5.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\winapp\python\python310\lib\site-packages (from requests>=2.25.0->spotipy) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\winapp\python\python310\lib\site-packages (from requests>=2.25.0->spotipy) (2023.11.17)
# Requirement already satisfied: idna<4,>=2.5 in c:\winapp\python\python310\lib\site-packages (from requests>=2.25.0->spotipy) (3.6)
# [notice] A new release of pip available: 22.2.2 -> 25.3
# [notice] To update, run: C:\WinApp\Python\Python310\python.exe -m pip install --upgrade pip

# %%
# !pip install dotenv
# Out:
# Requirement already satisfied: dotenv in c:\winapp\python\python310\lib\site-packages (0.9.9)
# Requirement already satisfied: python-dotenv in c:\winapp\python\python310\lib\site-packages (from dotenv) (1.2.1)
# [notice] A new release of pip available: 22.2.2 -> 25.3
# [notice] To update, run: C:\WinApp\Python\Python310\python.exe -m pip install --upgrade pip

# %%
from spotipy import Spotify
from spotipy.oauth2 import SpotifyOAuth

# %%
from dotenv import load_dotenv
import os

load_dotenv()

CLIENT_ID = os.getenv("SPOTIFY_CLIENT_ID")
CLIENT_SECRET = os.getenv("SPOTIFY_CLIENT_SECRET")
REDIRECT_URI = os.getenv("REDIRECT_URI")

# %%
SCOPE = "user-library-read user-top-read"

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
    client_id=CLIENT_ID,
    client_secret=CLIENT_SECRET,
    redirect_uri=REDIRECT_URI,
    scope=SCOPE,
    open_browser=True
))

# # Fetch saved tracks
# print("=== Saved Tracks ===")
# saved = sp.current_user_saved_tracks(limit=20)
# for item in saved['items']:
#     track = item['track']
#     print(track['name'], "-", track['artists'][0]['name'])

# Fetch top tracks
print("\n=== Top Tracks ===")
top = sp.current_user_top_tracks(limit=20, time_range='short_term')
for idx, item in enumerate(top['items']):
    print(f"{idx+1}. {item['artists'][0]['name']} — {item['name']}")
# Out:
# === Saved Tracks ===
# The Winner Takes It All - ABBA
